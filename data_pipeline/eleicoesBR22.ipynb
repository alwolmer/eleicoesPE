# %% [markdown]
# # Initialize notebook

# %%
# !pip install pandas geopandas numpy IPython -q

import pandas as pd
import geopandas as gpd
import numpy as np
from IPython.display import display

# %%
import os

project_root = os.getcwd()
os.listdir(project_root)
# Out:
# ['.config', 'sample_data']

# %%
# from google.colab import drive
# drive.mount ('/content/gdrive/', force_remount=True)

# %% [markdown]
# # Data preprocessing
# * Group and sum the election results by Municipio
# * Dissolve the census sectors by Municipio and filter out non-relevant columns (higher than state-level aggregation and urban sprawl flag)

# %% [markdown]
# # Processing electoral results
# * Download the zipped data from TSE, extract in memory and load into a pandas DataFrame
# * Filter the relevant columns and group the votes by municipio

# %%
import requests
import zipfile
import os
import pandas as pd
from io import BytesIO

# Define the URL for the dataset
UF = 'PE'
tse_cdn_url = f'https://cdn.tse.jus.br/estatistica/sead/odsele/votacao_secao/votacao_secao_2022_{UF}.zip'

# Download the zip file
response = requests.get(tse_cdn_url)
if response.status_code == 200:
    # Extract the zip file in memory
    with zipfile.ZipFile(BytesIO(response.content)) as zfile:
        # Find the .csv file within the extracted directory
        for file_name in zfile.namelist():
            if file_name.endswith('.csv'):
                # Read the CSV file directly from the zip archive
                with zfile.open(file_name) as csvfile:
                    votacao_UF = pd.read_csv(csvfile, delimiter=";", encoding="latin 1")

                # Print shape and column names
                print(votacao_UF.shape)
                print(votacao_UF.columns)
# Out:
# (2763316, 26)
# Index(['DT_GERACAO', 'HH_GERACAO', 'ANO_ELEICAO', 'CD_TIPO_ELEICAO',
#        'NM_TIPO_ELEICAO', 'NR_TURNO', 'CD_ELEICAO', 'DS_ELEICAO', 'DT_ELEICAO',
#        'TP_ABRANGENCIA', 'SG_UF', 'SG_UE', 'NM_UE', 'CD_MUNICIPIO',
#        'NM_MUNICIPIO', 'NR_ZONA', 'NR_SECAO', 'CD_CARGO', 'DS_CARGO',
#        'NR_VOTAVEL', 'NM_VOTAVEL', 'QT_VOTOS', 'NR_LOCAL_VOTACAO',
#        'SQ_CANDIDATO', 'NM_LOCAL_VOTACAO', 'DS_LOCAL_VOTACAO_ENDERECO'],
#       dtype='object')

# %%
cols = ['NR_TURNO', 'CD_MUNICIPIO', 'NM_MUNICIPIO', 'CD_CARGO', 'NR_VOTAVEL', 'SQ_CANDIDATO', 'QT_VOTOS']
cols_ = ['NR_TURNO', 'CD_MUNICIPIO', 'NM_MUNICIPIO', 'CD_CARGO', 'NR_VOTAVEL', 'SQ_CANDIDATO']

output_dir = f'intermediate'
# Ensure the output directory exists
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

voto_UF_abrev = votacao_UF[cols]
voto_UF_abrev = voto_UF_abrev.groupby(cols_, as_index=False)['QT_VOTOS'].sum()
voto_UF_abrev.columns = ['NR_TURNO', 'CD_MUN', 'NM_MUN', 'CD_CARGO', 'NR_VOTAVEL', 'SQ_CANDIDATO', 'QT_VOTOS']
voto_UF_abrev.to_csv(f"{project_root}/intermediate/votacao_mun_2022_{UF}_abrev.csv", index=False)

print(voto_UF_abrev.shape)
print(voto_UF_abrev.columns)
# Out:
# (83422, 7)
# Index(['NR_TURNO', 'CD_MUN', 'NM_MUN', 'CD_CARGO', 'NR_VOTAVEL',
#        'SQ_CANDIDATO', 'QT_VOTOS'],
#       dtype='object')

# %% [markdown]
# # Processing geographical geometries
# * Download the zipped data from IBGE, extract in memory and load into a geopandas GeoDataFrame
# * Filter the relevant columns and group the shapes by municipio

# %%
ibge_cdn_url = f"https://ftp.ibge.gov.br/Censos/Censo_Demografico_2022/Agregados_por_Setores_Censitarios_preliminares/malha_com_atributos/setores/json/UF/{UF}/{UF}_Malha_Preliminar_2022.zip"

# Download the zip file
response = requests.get(ibge_cdn_url)
if response.status_code == 200:
    # Extract the zip file in memory
    with zipfile.ZipFile(BytesIO(response.content)) as zfile:
        # Find the (geo) .json file within the extracted directory
        for file_name in zfile.namelist():
            if file_name.endswith('.json'):
                # Read the json file directly from the zip archive
                with zfile.open(file_name) as jsonfile:
                   malha_UF = gpd.read_file(jsonfile)

                # Print shape and column names
                print(malha_UF.shape)
                print(malha_UF.columns)
# Out:
# (17574, 30)
# Index(['CD_SETOR', 'AREA_KM2', 'CD_REGIAO', 'NM_REGIAO', 'CD_UF', 'NM_UF',
#        'CD_MUN', 'NM_MUN', 'CD_DIST', 'NM_DIST', 'CD_SUBDIST', 'NM_SUBDIST',
#        'CD_MICRO', 'NM_MICRO', 'CD_MESO', 'NM_MESO', 'CD_RGI', 'NM_RGI',
#        'CD_RGINT', 'NM_RGINT', 'CD_CONCURB', 'NM_CONCURB', 'v0001', 'v0002',
#        'v0003', 'v0004', 'v0005', 'v0006', 'v0007', 'geometry'],
#       dtype='object')

# %%
cols = ['CD_MUN', 'NM_MUN', 'CD_MICRO', 'NM_MICRO', 'CD_MESO',
        'NM_MESO', 'CD_RGI', 'NM_RGI', 'CD_RGINT', 'NM_RGINT', 'v0001', 'geometry']
cols_ = ['NM_MUN', 'CD_MICRO', 'NM_MICRO', 'CD_MESO',
        'NM_MESO', 'CD_RGI', 'NM_RGI', 'CD_RGINT', 'NM_RGINT']

agg_dict = {
    item: 'first' for item in cols_
}

agg_dict['v0001'] = 'sum'

malha_UF_abrev = malha_UF[cols].dissolve(by='CD_MUN', aggfunc=agg_dict, as_index=False)
malha_UF_abrev[cols]

malha_UF_abrev.to_file(f'{project_root}/intermediate/malha_{UF}_abrev.geojson', driver='GeoJSON')

print(malha_UF_abrev.shape)
print(malha_UF_abrev.columns)
# Out:
# (185, 12)
# Index(['CD_MUN', 'geometry', 'NM_MUN', 'CD_MICRO', 'NM_MICRO', 'CD_MESO',
#        'NM_MESO', 'CD_RGI', 'NM_RGI', 'CD_RGINT', 'NM_RGINT', 'v0001'],
#       dtype='object')

# %% [markdown]
# # Processing state candidate data
# * Download the zipped data from TSE, extract in memory and load into a geopandas GeoDataFrame
# * Filter the relevant columns and select only candidates from the selected state

# %%
# Define the URL for the dataset
tse_cdn_url_cand = f'https://cdn.tse.jus.br/estatistica/sead/odsele/consulta_cand/consulta_cand_2022.zip'

df_list = []

# Download the zip file
response = requests.get(tse_cdn_url_cand)
if response.status_code == 200:
    # Extract the zip file in memory
    with zipfile.ZipFile(BytesIO(response.content)) as zfile:
        # Find the .csv file within the extracted directory
        for file_name in zfile.namelist():
            if file_name.endswith('BRASIL.csv'):
                # Read the CSV file directly from the zip archive
                with zfile.open(file_name) as csvfile:
                    cand_BR = pd.read_csv(csvfile, delimiter=";", encoding="latin 1")

                # Print shape and column names
                print(cand_BR.shape)
                print(cand_BR.columns)
# Out:
# (29314, 50)
# Index(['DT_GERACAO', 'HH_GERACAO', 'ANO_ELEICAO', 'CD_TIPO_ELEICAO',
#        'NM_TIPO_ELEICAO', 'NR_TURNO', 'CD_ELEICAO', 'DS_ELEICAO', 'DT_ELEICAO',
#        'TP_ABRANGENCIA_ELEICAO', 'SG_UF', 'SG_UE', 'NM_UE', 'CD_CARGO',
#        'DS_CARGO', 'SQ_CANDIDATO', 'NR_CANDIDATO', 'NM_CANDIDATO',
#        'NM_URNA_CANDIDATO', 'NM_SOCIAL_CANDIDATO', 'NR_CPF_CANDIDATO',
#        'DS_EMAIL', 'CD_SITUACAO_CANDIDATURA', 'DS_SITUACAO_CANDIDATURA',
#        'TP_AGREMIACAO', 'NR_PARTIDO', 'SG_PARTIDO', 'NM_PARTIDO',
#        'NR_FEDERACAO', 'NM_FEDERACAO', 'SG_FEDERACAO',
#        'DS_COMPOSICAO_FEDERACAO', 'SQ_COLIGACAO', 'NM_COLIGACAO',
#        'DS_COMPOSICAO_COLIGACAO', 'SG_UF_NASCIMENTO', 'DT_NASCIMENTO',
#        'NR_TITULO_ELEITORAL_CANDIDATO', 'CD_GENERO', 'DS_GENERO',
#        'CD_GRAU_INSTRUCAO', 'DS_GRAU_INSTRUCAO', 'CD_ESTADO_CIVIL',
#        'DS_ESTADO_CIVIL', 'CD_COR_RACA', 'DS_COR_RACA', 'CD_OCUPACAO',
#        'DS_OCUPACAO', 'CD_SIT_TOT_TURNO', 'DS_SIT_TOT_TURNO'],
#       dtype='object')

# %%
# situacao_cand_key = cand_PE[['CD_SITUACAO_CANDIDATURA', 'DS_SITUACAO_CANDIDATURA']].drop_duplicates()
# situacao_eleicao_key = cand_PE[['CD_SIT_TOT_TURNO', 'DS_SIT_TOT_TURNO']].drop_duplicates()

# TODO: collect gender, education, racial data in order to allow for filtering candidates by those traits
cols = ['NR_TURNO', 'CD_CARGO', 'SQ_CANDIDATO', 'NM_URNA_CANDIDATO', 'NM_CANDIDATO', 'NR_CANDIDATO', 'NR_PARTIDO', 'SG_PARTIDO', 'CD_SITUACAO_CANDIDATURA', 'CD_SIT_TOT_TURNO']

cand_UF = cand_BR[cand_BR['SG_UF'] == UF]
cand_UF_abrev = cand_UF[cols].copy()
cand_UF_abrev.to_csv(f"{project_root}/intermediate/cand_2022_{UF}_abrev.csv", index=False)

print(cand_UF_abrev.shape)
print(cand_UF_abrev.columns)
# Out:
# (1142, 10)
# Index(['NR_TURNO', 'CD_CARGO', 'SQ_CANDIDATO', 'NM_URNA_CANDIDATO',
#        'NM_CANDIDATO', 'NR_CANDIDATO', 'NR_PARTIDO', 'SG_PARTIDO',
#        'CD_SITUACAO_CANDIDATURA', 'CD_SIT_TOT_TURNO'],
#       dtype='object')

# %% [markdown]
# # Loading candidate official photos
# * Download the zipped data from TSE
# * Extract in memory, standardize the extension (all to .jpg) and save to the render directory

# %%
# Define the URL for the dataset
tse_cdn_url_photos = f'https://cdn.tse.jus.br/estatistica/sead/eleicoes/eleicoes2022/fotos/foto_cand2022_{UF}_div.zip'

output_dir = f'render/fotos{UF}2022'
# Ensure the output directory exists
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Download the zip file
response = requests.get(tse_cdn_url_photos)
if response.status_code == 200:
    # Extract the zip file in memory
    with zipfile.ZipFile(BytesIO(response.content)) as zfile:
        # Loop through all the files in the zip archive
        for file_name in zfile.namelist():
            # Only consider .jpeg and .jpg files
            if file_name.lower().endswith(('.jpeg', '.jpg')):
                # Remove the first three characters and "_div"
                base_name = os.path.basename(file_name)
                numeric_part = base_name[3:].replace('_div', '')

                # Remove the existing file extension using string slicing
                numeric_part_without_ext = numeric_part.rsplit('.', 1)[0]

                # Standardize the extension to .jpg
                new_file_name = numeric_part_without_ext + '.jpg'

                # Save the file with the new extension in the output directory
                with zfile.open(file_name) as source_file:
                    output_path = os.path.join(output_dir, os.path.basename(new_file_name))
                    with open(output_path, 'wb') as dest_file:
                        dest_file.write(source_file.read())
        print(f'Downloaded and extracted photos to {output_dir}')
# Out:
# Downloaded and extracted photos to render/fotosPE2022

# %% [markdown]
# # Load preprocessed data

# %%
voto_UF_abrev = pd.read_csv(f"{project_root}/intermediate/votacao_mun_2022_{UF}_abrev.csv")
malha_UF_abrev = gpd.read_file(f'{project_root}/intermediate/malha_{UF}_abrev.geojson')
cand_UF_abrev = pd.read_csv(f"{project_root}/intermediate/cand_2022_{UF}_abrev.csv")

# %% [markdown]
# # Fix and fill data
# * TSE (electoral court) and IBGE (geography and statistics institute) both use codes for Municipios, but the systems are no compatible; fuzzy matching by municipio name allows us to assign the IBGE codes to the municipios in the electoral results
# * Compute the total votes and total valid votes for each municipio to calculate metrics for candidates
# * Separate the data of interest: nominal votes and legend (party) votes
# * Filter municipio geographic data to only contain IBGE code, name and shapes

# %%
try:
  from rapidfuzz import process, fuzz
except:
  # !pip install rapidfuzz -q
  from rapidfuzz import process, fuzz

# municipios ground truth
municipios_gt = malha_UF_abrev[['CD_MUN','NM_MUN']].drop_duplicates()
municipios_gt['NM_MUN'] = municipios_gt['NM_MUN'].str.lower().str.strip()

match_dict = {}

def fuzzy_match(mun_name, mun_df, min_score=80):
    if mun_name in match_dict:
        return match_dict[mun_name]
    best_match = process.extractOne(mun_name.lower().strip(), mun_df['NM_MUN'], scorer=fuzz.ratio, score_cutoff=min_score)
    if best_match:
        matched_row = mun_df[mun_df['NM_MUN'] == best_match[0]]
        code = matched_row['CD_MUN'].values[0]
        match_dict[mun_name] = code
        return code
    return None

voto_UF_corrected = voto_UF_abrev.copy()
display(voto_UF_corrected.head())
voto_UF_corrected['CD_MUN'] = voto_UF_corrected['NM_MUN'].apply(lambda x: fuzzy_match(x, municipios_gt))
voto_UF_corrected.drop(columns=['NM_MUN'], inplace=True)
voto_UF_corrected = voto_UF_corrected[['CD_MUN', 'NR_TURNO', 'CD_CARGO', 'NR_VOTAVEL', 'SQ_CANDIDATO', 'QT_VOTOS']]

display(voto_UF_corrected.head())

voto_UF_corrected.to_csv(f"{project_root}/intermediate/votacao_mun_2022_{UF}_corrected.csv", index=False)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 22.7 MB/s eta 0:00:00
#    NR_TURNO  CD_MUN   NM_MUN  CD_CARGO  NR_VOTAVEL  SQ_CANDIDATO  QT_VOTOS
# 0         1   23000  QUIXABA         3          14  170001618273         7
# 1         1   23000  QUIXABA         3          22  170001602587       213
# 2         1   23000  QUIXABA         3          40  170001618087      1011
# 3         1   23000  QUIXABA         3          44  170001604111      2044
# 4         1   23000  QUIXABA         3          45  170001604087        56
#     CD_MUN  NR_TURNO  CD_CARGO  NR_VOTAVEL  SQ_CANDIDATO  QT_VOTOS
# 0  2611533         1         3          14  170001618273         7
# 1  2611533         1         3          22  170001602587       213
# 2  2611533         1         3          40  170001618087      1011
# 3  2611533         1         3          44  170001604111      2044
# 4  2611533         1         3          45  170001604087        56

# %%
voto_mun = voto_UF_corrected.copy()
voto_mun_valido = voto_UF_corrected[voto_UF_corrected['SQ_CANDIDATO'] != -1]
voto_mun_nominal = voto_UF_corrected[(voto_UF_corrected['SQ_CANDIDATO'] != -1) | (voto_UF_corrected['SQ_CANDIDATO'] == -3)]
voto_mun_legenda = voto_UF_corrected[voto_UF_corrected['SQ_CANDIDATO'] == -3]

# Step 1: Copy the data
voto_mun_partido = voto_mun_valido.copy()

# Step 2: Modify 'NR_VOTAVEL' to only keep the first two characters
voto_mun_partido['NR_VOTAVEL'] = voto_mun_partido['NR_VOTAVEL'].astype(str).str[:2]

# Step 3: Group by the modified 'NR_VOTAVEL' and other columns
cols_ = ['NR_TURNO', 'CD_MUN', 'CD_CARGO', 'NR_VOTAVEL']
voto_mun_partido = voto_mun_partido.groupby(cols_, as_index=False).agg({'QT_VOTOS': 'sum'}).sort_values(by=['NR_TURNO', 'CD_MUN', 'CD_CARGO', 'NR_VOTAVEL'])

# Step 4: Optionally drop 'SQ_CANDIDATO' (if no longer needed)
voto_mun_partido.drop(columns=['SQ_CANDIDATO'], inplace=True, errors='ignore')

# Step 5: Display or return the result
display(voto_mun_partido[(voto_mun_partido['CD_CARGO'] == 6) & ((voto_mun_partido['NR_VOTAVEL'] == '40'))].head(50))

voto_mun_total = voto_mun.groupby(['CD_CARGO', 'NR_TURNO', 'CD_MUN'], as_index=False).agg({'QT_VOTOS': 'sum'})
voto_mun_valido_total = voto_mun_valido.groupby(['CD_CARGO', 'NR_TURNO', 'CD_MUN'], as_index=False).agg({'QT_VOTOS': 'sum'})
# Out:
#       NR_TURNO   CD_MUN  CD_CARGO NR_VOTAVEL  QT_VOTOS
# 40           1  2600054         6         40      7384
# 119          1  2600104         6         40      8115
# 190          1  2600203         6         40      2688
# 265          1  2600302         6         40      5406
# 339          1  2600401         6         40       365
# 417          1  2600500         6         40       432
# 490          1  2600609         6         40      1846
# 564          1  2600708         6         40      3483
# 637          1  2600807         6         40      5974
# 712          1  2600906         6         40      3704
# 785          1  2601003         6         40       283
# 857          1  2601052         6         40      2218
# 929          1  2601102         6         40      6290
# 1006         1  2601201         6         40      5353
# 1077         1  2601300         6         40       113
# 1149         1  2601409         6         40       757
# 1219         1  2601508         6         40       159
# 1293         1  2601607         6         40      2145
# 1367         1  2601706         6         40      4139
# 1443         1  2601805         6         40       257
# 1515         1  2601904         6         40      5019
# 1590         1  2602001         6         40      8638
# 1667         1  2602100         6         40       686
# 1740         1  2602209         6         40       769
# 1814         1  2602308         6         40      1881
# 1885         1  2602407         6         40       529
# 1950         1  2602506         6         40       467
# 2018         1  2602605         6         40      1562
# 2092         1  2602704         6         40       926
# 2166         1  2602803         6         40      1814
# 2246         1  2602902         6         40     10474
# 2324         1  2603009         6         40      2857
# 2399         1  2603108         6         40       389
# 2476         1  2603207         6         40       773
# 2544         1  2603306         6         40       110
# 2610         1  2603405         6         40       361
# 2682         1  2603454         6         40     13256
# 2757         1  2603504         6         40      1002
# 2831         1  2603603         6         40      1442
# 2902         1  2603702         6         40      1045
# 2973         1  2603801         6         40       496
# 3045         1  2603900         6         40      6309
# 3115         1  2603926         6         40      1998
# 3189         1  2604007         6         40      6990
# 3268         1  2604106         6         40      9924
# 3341         1  2604155         6         40      3459
# 3414         1  2604205         6         40      3801
# 3486         1  2604304         6         40       281
# 3553         1  2604403         6         40      3220
# 3626         1  2604502         6         40      1152

# %%
malha_UF_mun = malha_UF_abrev[['CD_MUN', 'NM_MUN', 'geometry']].copy()
# malha_UF_mun.head()
malha_UF_int = malha_UF_abrev.dissolve(by='CD_RGI', as_index=False)[['CD_RGI', 'NM_RGI', 'geometry']]

# %% [markdown]
# # Saving to file the components necessary for rendering

# %%
cand_UF_abrev.to_csv(f"{project_root}/render/cand_abrev_{UF}_2022.csv", index=False)

voto_mun.to_csv(f"{project_root}/render/voto_mun_{UF}_2022.csv", index=False)
voto_mun_valido.to_csv(f"{project_root}/render/voto_mun_valido_{UF}_2022.csv", index=False)
voto_mun_partido.to_csv(f"{project_root}/render/voto_mun_partido_{UF}_2022.csv", index=False)

voto_mun_total.to_csv(f"{project_root}/render/voto_mun_{UF}_total_2022.csv", index=False)
voto_mun_valido_total.to_csv(f"{project_root}/render/voto_mun_valido_{UF}_total_2022.csv", index=False)

malha_UF_mun.to_file(f"{project_root}/render/malha_{UF}_mun.geojson", driver='GeoJSON')
malha_UF_int.to_file(f"{project_root}/render/malha_{UF}_int.geojson", driver='GeoJSON')

# %%
# !zip -r render_data.zip render/
# Out:
#   adding: render/ (stored 0%)
#   adding: render/voto_mun_valido_PE_total_2022.csv (deflated 69%)
#   adding: render/voto_mun_PE_2022.csv (deflated 83%)
#   adding: render/cand_abrev_PE_2022.csv (deflated 70%)
#   adding: render/voto_mun_PE_total_2022.csv (deflated 76%)
#   adding: render/fotosPE2022/ (stored 0%)
#   adding: render/fotosPE2022/170001618417.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001619700.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001723379.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001609283.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609301.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001608962.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001613271.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609030.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001619986.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001604084.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001610249.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001722272.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001718134.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609883.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001613433.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001605472.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001613428.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001619707.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001595423.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001595442.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001722258.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001718141.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001595465.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001613435.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001618409.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618601.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001595421.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001735574.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001619896.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001723375.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001595433.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618935.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001620399.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001595468.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609658.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618087.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001718770.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001609071.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001608965.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001608963.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001722273.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001608978.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001715429.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001722249.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001613424.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609070.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609130.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001610731.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001620367.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001722248.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001718776.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001723367.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001610740.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609293.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001613429.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001722262.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001602580.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001718007.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001610567.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001619894.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001723343.jpg (deflated 6%)
#   adding: render/fotosPE2022/170001619589.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001619685.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001609261.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001610565.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001605474.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001620364.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001718009.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609023.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001595475.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001610415.jpg (deflated 5%)
#   adding: render/fotosPE2022/170001723349.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001620396.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001723350.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001723407.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001618088.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609085.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001610715.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001620371.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609652.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001718016.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001609028.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001605464.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609645.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001730689.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609114.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001618618.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618408.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001738824.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001610714.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001722254.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001608977.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001723378.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001605488.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609074.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001609121.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001608961.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001619583.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001595453.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001596602.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609884.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001610574.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001724249.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001613439.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618272.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609636.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609651.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001595440.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001718765.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001609302.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001602571.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609292.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001610729.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001605470.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001610749.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609296.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001619708.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001608980.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001605490.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001717461.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001733443.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001613821.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001723356.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001718659.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001595456.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001595429.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618132.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001613432.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001619599.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001604096.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001618838.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001610728.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001722535.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001605481.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001619688.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001609862.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001604087.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001620150.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001610399.jpg (deflated 5%)
#   adding: render/fotosPE2022/170001619714.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001613262.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001722257.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618604.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001620147.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618734.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609174.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001609080.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001610407.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001610576.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001610398.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001724245.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609042.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001602579.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001728102.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001613430.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001718138.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609286.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001605492.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001723358.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001613438.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001600160.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609852.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609930.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001618724.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001602560.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001730140.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001613427.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001604095.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001609282.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001605495.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001722250.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001619586.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001610416.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001610418.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001605475.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001613431.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001718132.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618851.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001609038.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001604097.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001610748.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001717465.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001613275.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001605473.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001604111.jpg (deflated 5%)
#   adding: render/fotosPE2022/170001618402.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609262.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618397.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001619692.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001619596.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001715590.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609657.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001618836.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001608747.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618762.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001620146.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001609291.jpg (deflated 6%)
#   adding: render/fotosPE2022/170001610564.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001718662.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001619893.jpg (deflated 6%)
#   adding: render/fotosPE2022/170001605491.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001619724.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001723371.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001723359.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001619712.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001619584.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001739180.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001595469.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609872.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001610732.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001718142.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001717067.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001619593.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618840.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001604094.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001723377.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001613266.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618610.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001634979.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001619594.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001613425.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618130.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618745.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001608970.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001595434.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001718642.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609653.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618739.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001595426.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001619681.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001610413.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001620387.jpg (deflated 5%)
#   adding: render/fotosPE2022/170001602578.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609642.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618403.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001605497.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001619897.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001718658.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001595461.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001610395.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001608967.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001595473.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001729638.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001724247.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001605486.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001717290.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001609887.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001595448.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001619982.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001620372.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618398.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618845.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001620376.jpg (deflated 5%)
#   adding: render/fotosPE2022/170001595457.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609116.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001608960.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001718766.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001620397.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618942.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001722274.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001618940.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001723372.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001620370.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001596600.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001718777.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001717466.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609859.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001609119.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001604101.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001715433.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001718021.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001620390.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001634981.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001610414.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001609124.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001610724.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609638.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618396.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001634980.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001609298.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001619980.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001620393.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001610718.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618943.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001608957.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001634987.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001595424.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609290.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001619902.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001634989.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001715332.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001718780.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001718136.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609650.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001610742.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001715591.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609117.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609136.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609122.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001619981.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001602581.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618756.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609135.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609867.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001610733.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001605482.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001605469.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001595463.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001620145.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609032.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001722278.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001610721.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001609134.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001604070.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001595431.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618930.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001610400.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001718663.jpg (deflated 5%)
#   adding: render/fotosPE2022/170001609035.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618611.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001613423.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001619701.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001610410.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001722251.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001717341.jpg (deflated 17%)
#   adding: render/fotosPE2022/170001722253.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001613274.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001613173.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001610406.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001604112.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001605489.jpg (deflated 7%)
#   adding: render/fotosPE2022/170001604106.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609072.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001620402.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001620379.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001724241.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001739178.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001723364.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001619703.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609036.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001608954.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001608956.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001718775.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609067.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001609279.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001634984.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001722270.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001604066.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001723514.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001613267.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001618414.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609081.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609133.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618726.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001610753.jpg (deflated 6%)
#   adding: render/fotosPE2022/170001634991.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001613263.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001722271.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618928.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001718657.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001620381.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001717065.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001604085.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001610735.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001610569.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001619979.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001595464.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618852.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001596601.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618426.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609039.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001618429.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001608985.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618410.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001619013.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001715425.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618412.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618742.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618947.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001718005.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001715432.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001727901.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618735.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001723579.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001718778.jpg (deflated 6%)
#   adding: render/fotosPE2022/170001618849.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001718020.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001620391.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609084.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001639702.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001619892.jpg (deflated 5%)
#   adding: render/fotosPE2022/170001609875.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001595428.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001613422.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001618757.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001610401.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001609086.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001619723.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001602568.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001613255.jpg (deflated 5%)
#   adding: render/fotosPE2022/170001610394.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001618415.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001595427.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001722268.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001610719.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609928.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001609641.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609281.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001723182.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001620380.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001609120.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001613282.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001718767.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001724254.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001620149.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001722256.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001604093.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001620398.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001634996.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618273.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001723373.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001619987.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001595476.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001613420.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609112.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001620389.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001724741.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001610744.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001718143.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609861.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001610751.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001610737.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618731.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001718006.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001604105.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001723513.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001724259.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001595439.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001613411.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001608976.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001605496.jpg (deflated 6%)
#   adding: render/fotosPE2022/170001718025.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001609853.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001595441.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001732342.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001718028.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001619698.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001609857.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001620401.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001618420.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001620363.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618614.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001610738.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609304.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001619705.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001619690.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001717068.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001722259.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001613421.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001717464.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001602587.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001609175.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001619702.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001619721.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001619691.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609083.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618743.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001634994.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001730172.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001604083.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618932.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609640.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618760.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001717342.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618854.jpg (deflated 6%)
#   adding: render/fotosPE2022/170001618728.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618407.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609929.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609851.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001634978.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001610730.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001619709.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001619889.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001717062.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001596603.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001613279.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001610412.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001718764.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609866.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001613174.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001718650.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001739177.jpg (deflated 5%)
#   adding: render/fotosPE2022/170001609854.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001718024.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001718768.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609855.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001635001.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001723376.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001718654.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001609294.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001609129.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001718644.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001619687.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001610250.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001613442.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001718027.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001608964.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001605498.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618419.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618938.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001718008.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001610741.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618425.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001722276.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001724255.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001608983.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001620368.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609113.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001619895.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001718012.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609284.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001620383.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609659.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001604099.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609031.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001718664.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001601203.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001723348.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001595443.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618602.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001634992.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609871.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001613272.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001605479.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001608981.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001610402.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001602567.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001723211.jpg (deflated 5%)
#   adding: render/fotosPE2022/170001605493.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001722266.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001722280.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001722275.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618401.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001619592.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618754.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609078.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001619585.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001604102.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001722252.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001725493.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001608973.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001619901.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001721979.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001718653.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001613162.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609864.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001718643.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001595447.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001717288.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001609308.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001618853.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001605468.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609069.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001620388.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001610743.jpg (deflated 5%)
#   adding: render/fotosPE2022/170001595445.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001726025.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618846.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001619684.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001717459.jpg (deflated 6%)
#   adding: render/fotosPE2022/170001619706.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609271.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001618848.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001717061.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001718660.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001718137.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001619899.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001717468.jpg (deflated 17%)
#   adding: render/fotosPE2022/170001613278.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001722264.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001620377.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609868.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001619012.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001730690.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618844.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001723517.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001717463.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001723368.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001722263.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001715594.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001613413.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001602586.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618131.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618839.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001724675.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609264.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001619716.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001609029.jpg (deflated 15%)
#   adding: render/fotosPE2022/170001610570.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001722260.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001608958.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618619.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609115.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001602562.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001619683.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609089.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001595422.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001605484.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001722279.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001619696.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001610722.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001715593.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001726567.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001595425.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618761.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001619582.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001620374.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001595471.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001718655.jpg (deflated 6%)
#   adding: render/fotosPE2022/170001620373.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001602572.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609305.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001718139.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001610727.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001723365.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001736049.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618927.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001634993.jpg (deflated 6%)
#   adding: render/fotosPE2022/170001722267.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618607.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618606.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001609123.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001717064.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001619726.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001634997.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001619718.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001715427.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618937.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001608984.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618946.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001619588.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001619581.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001619719.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001608974.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001620142.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001733444.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001605465.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609088.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609033.jpg (deflated 6%)
#   adding: render/fotosPE2022/170001618758.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001609285.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609073.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001619689.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609267.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001609276.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001595452.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001595437.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001723366.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001634988.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609877.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001609646.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001602570.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618933.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618395.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618837.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001722265.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001596605.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001604068.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618411.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609272.jpg (deflated 5%)
#   adding: render/fotosPE2022/170001609037.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001718023.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001635000.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001595472.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001613436.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609288.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001602577.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609263.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001595454.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609881.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001620148.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609656.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001718029.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001620392.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001718652.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618936.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001613270.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001723362.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609044.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001718018.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001723353.jpg (deflated 6%)
#   adding: render/fotosPE2022/170001620151.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001730684.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001618427.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001619695.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618945.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001717122.jpg (deflated 6%)
#   adding: render/fotosPE2022/170001717060.jpg (deflated 6%)
#   adding: render/fotosPE2022/170001724874.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001610717.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001717072.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001724251.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001731857.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001619587.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618926.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001726028.jpg (deflated 6%)
#   adding: render/fotosPE2022/170001613426.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001613440.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001619704.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001620385.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001718645.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001718771.jpg (deflated 5%)
#   adding: render/fotosPE2022/170001723347.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001718773.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001619579.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001602573.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001735036.jpg (deflated 5%)
#   adding: render/fotosPE2022/170001619693.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001620366.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001604103.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609863.jpg (deflated 6%)
#   adding: render/fotosPE2022/170001721978.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001609637.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001605467.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001605471.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001618931.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001608972.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001609176.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001610750.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001723345.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001619720.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001608955.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001619729.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001718762.jpg (deflated 5%)
#   adding: render/fotosPE2022/170001609303.jpg (deflated 6%)
#   adding: render/fotosPE2022/170001619686.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618730.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001610572.jpg (deflated 6%)
#   adding: render/fotosPE2022/170001595458.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618729.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001619727.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001620394.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001734021.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001620365.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618733.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001718013.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001723351.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001609644.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609289.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001609882.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001718017.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609043.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001715430.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001618749.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001619722.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001602563.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001723370.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609026.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609878.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001595466.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001724252.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001724243.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001610405.jpg (deflated 5%)
#   adding: render/fotosPE2022/170001618617.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001718641.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001605477.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001618944.jpg (deflated 6%)
#   adding: render/fotosPE2022/170001618413.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001620369.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609079.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609297.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001605487.jpg (deflated 7%)
#   adding: render/fotosPE2022/170001717458.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001723380.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001618736.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001634999.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001613277.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001613265.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001723369.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001610397.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001600159.jpg (deflated 6%)
#   adding: render/fotosPE2022/170001609931.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001610950.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618841.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001595446.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001718145.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001608748.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001620382.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001602569.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001619694.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618616.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001595432.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001610403.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001723381.jpg (deflated 0%)
# ...
#   adding: render/fotosPE2022/170001715431.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001601204.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618605.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001595455.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001608959.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609299.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001610404.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001722269.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001610568.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001715592.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001595438.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001595436.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001610726.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001596604.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001723357.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618737.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001613419.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001618727.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609635.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001604107.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001718760.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001715331.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001620384.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609266.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001613276.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001604071.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001619715.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001609126.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001718772.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618738.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609082.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001718648.jpg (deflated 6%)
#   adding: render/fotosPE2022/170001608969.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001609265.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001610769.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001618620.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618856.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001601202.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001717289.jpg (deflated 17%)
#   adding: render/fotosPE2022/170001602565.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001717069.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001718646.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001595430.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001718015.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001610571.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001595462.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001601200.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001734022.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001608746.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001609856.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618847.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618613.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001722255.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001718026.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001610408.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001724257.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001620143.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001608968.jpg (deflated 5%)
#   adding: render/fotosPE2022/170001715428.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001610720.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001604098.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001602582.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001718144.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618405.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609274.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609132.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001618855.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001724260.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001604100.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001723354.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001715595.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001718639.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001619900.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001718011.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609876.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001602576.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618609.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001618725.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618622.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001604092.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618400.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001724674.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001595435.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001723363.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001613283.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001610736.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001715426.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001609295.jpg (deflated 5%)
#   adding: render/fotosPE2022/170001721977.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001609655.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618418.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001717121.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001595474.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001613412.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001610393.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001634986.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001619682.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001595449.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001723374.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001729155.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001609278.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001613273.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609273.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618621.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001609270.jpg (deflated 5%)
#   adding: render/fotosPE2022/170001618615.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001620400.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001619600.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001722277.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001717063.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609858.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001723360.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001613434.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618732.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609027.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609870.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001610566.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609034.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001605483.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618850.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001620144.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001718640.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001723352.jpg (deflated 5%)
#   adding: render/fotosPE2022/170001724742.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609860.jpg (deflated 5%)
#   adding: render/fotosPE2022/170001620140.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001718022.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001601201.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001726026.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001718014.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001634990.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609128.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001609869.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001604104.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001618612.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001717462.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001718761.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001620395.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618752.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001619898.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618428.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001610746.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001608971.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001619728.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001604069.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001619591.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618753.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001619890.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609309.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001718010.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001610951.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001718774.jpg (deflated 5%)
#   adding: render/fotosPE2022/170001724740.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001613269.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001595477.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618422.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001619590.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609065.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001610248.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001608979.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618722.jpg (deflated 5%)
#   adding: render/fotosPE2022/170001619595.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001728608.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618941.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001718647.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001595459.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001595444.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609287.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001723346.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001605466.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001717120.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001620141.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001735151.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001619598.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609087.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001619891.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001619602.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609118.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001608952.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001620378.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609277.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001613264.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609643.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001613161.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001722261.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001605485.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609076.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001609025.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001610573.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609269.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001618404.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609873.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609886.jpg (deflated 5%)
#   adding: render/fotosPE2022/170001723355.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001718781.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001618424.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001723361.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609654.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001619984.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001619983.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001618751.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609639.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001717460.jpg (deflated 17%)
#   adding: render/fotosPE2022/170001610575.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001609306.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001602575.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001610739.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001717066.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618608.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001595467.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001619699.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001610443.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001602566.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001718140.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001717070.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001602564.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618929.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001619711.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001618755.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001718133.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001723515.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001610725.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001602542.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001609647.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001610716.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001613254.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001618399.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618416.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001715192.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001723516.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001738823.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001610734.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001618750.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001619725.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609879.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618744.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001619597.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001605480.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001618746.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001610409.jpg (deflated 4%)
#   adding: render/fotosPE2022/170001609064.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001724264.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001619988.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001610747.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001718649.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001718763.jpg (deflated 17%)
#   adding: render/fotosPE2022/170001609268.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001718769.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001604108.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001730685.jpg (deflated 3%)
#   adding: render/fotosPE2022/170001634985.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001618603.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001609131.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001610745.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609040.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001718651.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001609075.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001718019.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001608953.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001610411.jpg (deflated 2%)
#   adding: render/fotosPE2022/170001602574.jpg (deflated 0%)
#   adding: render/fotosPE2022/170001619717.jpg (deflated 1%)
#   adding: render/fotosPE2022/170001618763.jpg (deflated 6%)
#   adding: render/voto_mun_valido_PE_2022.csv (deflated 84%)
#   adding: render/voto_mun_partido_PE_2022.csv (deflated 86%)
#   adding: render/malha_PE_mun.geojson (deflated 69%)
